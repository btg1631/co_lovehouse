# %%
import pandas as pd

# %%
get_data = pd.read_csv('./data/project_coliving.gatheringdatas.csv')
get_data
# Out:
#                           _id          title         roomName gender roomType  \
# 0    65d7f75e9f73bd1ba0885a08  동거동락X작심하우스 논현             201호     공용      그 외
# 1    65d7f75e9f73bd1ba0885a09  동거동락X작심하우스 논현             202호     공용      그 외
# 2    65d7f75e9f73bd1ba0885a0a  동거동락X작심하우스 논현             203호     공용      그 외
# 3    65d7f75e9f73bd1ba0885a0b  동거동락X작심하우스 논현             204호     공용      그 외
# 4    65d7f75e9f73bd1ba0885a0c  동거동락X작심하우스 논현             205호     공용      그 외
# ..                        ...            ...              ...    ...      ...
# 846  65d804a5075f5310e064971b        맹그로브 신설            Buddy     공용      그 외
# 847  65d804a5075f5310e064971c        맹그로브 신설             Bunk     공용      그 외
# 848  65d804a5075f5310e064971d        맹그로브 숭인   Single Compact     공용      1인실
# 849  65d804a5075f5310e064971e        맹그로브 숭인  Single Standard     공용      1인실
# 850  65d804a5075f5310e064971f        맹그로브 숭인              Duo     공용      그 외
#
#          py     deposit   rentFee region brandType  \
# 0       6.㎡    950,000원  355,000원    언주역     일반사업자
# 1        6㎡    950,000원  355,000원    언주역     일반사업자
# 2      6.4㎡    950,000원  440,000원    언주역     일반사업자
# 3        6㎡    950,000원  355,000원    언주역     일반사업자
# 4        6㎡    950,000원  420,000원    언주역     일반사업자
# ..      ...         ...       ...    ...       ...
# 846     15㎡  3,000,000원  570,000원   신설동역      맹그로브
# 847     15㎡  3,000,000원  540,000원   신설동역      맹그로브
# 848     12㎡  3,000,000원  550,000원    창신역      맹그로브
# 849     15㎡  3,000,000원  630,000원    창신역      맹그로브
# 850  23.95㎡  3,000,000원  590,000원    창신역      맹그로브
#
#                                             roomOption  \
# 0    ▶ 공용 가전 : 세탁기 / 건조기\n▶ 부엌 가전 : 냉장고 / 전자레인지 / 밥...
# 1    ▶ 공용 가전 : 세탁기 / 건조기\n▶ 부엌 가전 : 냉장고 / 전자레인지 / 밥...
# 2    ▶ 공용 가전 : 세탁기 / 건조기\n▶ 부엌 가전 : 냉장고 / 전자레인지 / 밥...
# 3    ▶ 공용 가전 : 세탁기 / 건조기\n▶ 부엌 가전 : 냉장고 / 전자레인지 / 밥...
# 4    ▶ 공용 가전 : 세탁기 / 건조기\n▶ 부엌 가전 : 냉장고 / 전자레인지 / 밥...
# ..                                                 ...
# 846  책상, 의자, 침대, 옷장, 수납장, 냉난방기, 미니 냉장고, 매트리스, 커튼, 침...
# 847  책상, 의자, 침대, 옷장, 수납장, 냉난방기, 미니 냉장고, 매트리스, 커튼, 침...
# 848  책상, 의자, 침대, 옷장, 수납장, 냉난방기, 공기청정시설, 미니 냉장고, 매트리...
# 849  책상, 의자, 침대, 옷장, 수납장, 냉난방기, 공기청정시설, 미니 냉장고, 매트리...
# 850  책상, 의자, 침대, 옷장, 수납장, 냉난방기, 공기청정시설, 미니 냉장고, 매트리...
#
#                                                    url  \
# 0    https://dgdr.co.kr/branch/view.html?search_tex...
# 1    https://dgdr.co.kr/branch/view.html?search_tex...
# 2    https://dgdr.co.kr/branch/view.html?search_tex...
# 3    https://dgdr.co.kr/branch/view.html?search_tex...
# 4    https://dgdr.co.kr/branch/view.html?search_tex...
# ..                                                 ...
# 846           https://mangrove.city/locations/sinseol/
# 847           https://mangrove.city/locations/sinseol/
# 848           https://mangrove.city/locations/soongin/
# 849           https://mangrove.city/locations/soongin/
# 850           https://mangrove.city/locations/soongin/
#
#                                                 imgUrl
# 0    https://dgdr.co.kr/upload/jijum/238342658_Gf6X...
# 1    https://dgdr.co.kr/upload/jijum/238342658_Gf6X...
# 2    https://dgdr.co.kr/upload/jijum/238342658_Gf6X...
# 3    https://dgdr.co.kr/upload/jijum/238342658_Gf6X...
# 4    https://dgdr.co.kr/upload/jijum/238342658_Gf6X...
# ..                                                 ...
# 846  https://mangrove.city/wp-content/uploads/2021/...
# 847  https://mangrove.city/wp-content/uploads/2021/...
# 848  https://mangrove.city/wp-content/uploads/2021/...
# 849  https://mangrove.city/wp-content/uploads/2021/...
# 850  https://mangrove.city/wp-content/uploads/2021/...
#
# [851 rows x 13 columns]

# %%
station_data = pd.read_csv('./data/station_location.csv')
station_data
# Out:
#       연번   역번호  호선           역명         역전화번호                       도로명주소  \
# 0      1   150   1           서울  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1      2   151   1           시청  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 2      3   152   1           종각  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
# 3      4   153   1         종로3가  02-6110-1301    서울특별시 종로구 종로 지하129(종로3가)
# 4      5   154   1         종로5가  02-6110-1291    서울특별시 종로구 종로 지하216(종로5가)
# ..   ...   ...  ..          ...           ...                         ...
# 283  284  4134   9         송파나루  02-2656-0934  서울특별시 송파구 백제고분로 지하446(방이동)
# 284  285  4135   9         한성백제  02-2656-0935   서울특별시 송파구 위례성대로 지하29(방이동)
# 285  286  4136   9  올림픽공원(한국체대)  02-2656-0936  서울특별시 송파구 양재대로 지하1233(방이동)
# 286  287  4137   9         둔촌오륜  02-2656-0937   서울특별시 강동구 강동대로 지하303(둔촌동)
# 287  288  4138   9       중앙보훈병원  02-2656-0938    서울특별시 강동구 동남로 지하625(둔촌동)
#
#                                 지번주소
# 0      서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 1           서울특별시 중구 정동 5-5 시청역(1호선)
# 2         서울특별시 종로구 종로1가 54 종각역(1호선)
# 3     서울특별시 종로구 종로3가 10-5 종로3가역(1호선)
# 4     서울특별시 종로구 종로5가 82-1 종로5가역(1호선)
# ..                               ...
# 283       서울특별시 송파구 방이동 2 송파나루역(9호선)
# 284   서울특별시 송파구 방이동 88-17 한성백제역(9호선)
# 285  서울특별시 송파구 방이동 89-28 올림픽공원역(9호선)
# 286   서울특별시 강동구 둔촌동 227-7 둔촌오륜역(9호선)
# 287   서울특별시 강동구 둔촌동 8-1 중앙보훈병원역(9호선)
#
# [288 rows x 7 columns]

# %%
import re

# %%
def del_gwalho(get_list):
    station_except = []
    for i in get_list:
        i = re.split(r'[()-]', i)[0]
        station_except.append(i)
    return station_except

# %%
station_data['del_staion'] = del_gwalho(station_data['역명'])
station_data
# Out:
#       연번   역번호  호선           역명         역전화번호                       도로명주소  \
# 0      1   150   1           서울  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1      2   151   1           시청  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 2      3   152   1           종각  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
# 3      4   153   1         종로3가  02-6110-1301    서울특별시 종로구 종로 지하129(종로3가)
# 4      5   154   1         종로5가  02-6110-1291    서울특별시 종로구 종로 지하216(종로5가)
# ..   ...   ...  ..          ...           ...                         ...
# 283  284  4134   9         송파나루  02-2656-0934  서울특별시 송파구 백제고분로 지하446(방이동)
# 284  285  4135   9         한성백제  02-2656-0935   서울특별시 송파구 위례성대로 지하29(방이동)
# 285  286  4136   9  올림픽공원(한국체대)  02-2656-0936  서울특별시 송파구 양재대로 지하1233(방이동)
# 286  287  4137   9         둔촌오륜  02-2656-0937   서울특별시 강동구 강동대로 지하303(둔촌동)
# 287  288  4138   9       중앙보훈병원  02-2656-0938    서울특별시 강동구 동남로 지하625(둔촌동)
#
#                                 지번주소 del_staion
# 0      서울특별시 중구 남대문로5가 73-6 서울역(1호선)         서울
# 1           서울특별시 중구 정동 5-5 시청역(1호선)         시청
# 2         서울특별시 종로구 종로1가 54 종각역(1호선)         종각
# 3     서울특별시 종로구 종로3가 10-5 종로3가역(1호선)       종로3가
# 4     서울특별시 종로구 종로5가 82-1 종로5가역(1호선)       종로5가
# ..                               ...        ...
# 283       서울특별시 송파구 방이동 2 송파나루역(9호선)       송파나루
# 284   서울특별시 송파구 방이동 88-17 한성백제역(9호선)       한성백제
# 285  서울특별시 송파구 방이동 89-28 올림픽공원역(9호선)      올림픽공원
# 286   서울특별시 강동구 둔촌동 227-7 둔촌오륜역(9호선)       둔촌오륜
# 287   서울특별시 강동구 둔촌동 8-1 중앙보훈병원역(9호선)     중앙보훈병원
#
# [288 rows x 8 columns]

# %%
station_data['지번주소'] = station_data['지번주소'].fillna('')

# %%
def split_data(get_list):
    get_dong = []
    for i in get_list:
        juso = list(i.split())
        for j in juso:
            if j[-1] == '동':
                j = re.sub(r'\d', '', j)
                get_dong.append(j)
                break
            elif j[-1] == '가':
                get_dong.append(j)
                break
        else:
            get_dong.append('')
    return get_dong

# %%
station_data['동추출'] = split_data(station_data['지번주소'])
station_data
# Out:
#       연번   역번호  호선           역명         역전화번호                       도로명주소  \
# 0      1   150   1           서울  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1      2   151   1           시청  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 2      3   152   1           종각  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
# 3      4   153   1         종로3가  02-6110-1301    서울특별시 종로구 종로 지하129(종로3가)
# 4      5   154   1         종로5가  02-6110-1291    서울특별시 종로구 종로 지하216(종로5가)
# ..   ...   ...  ..          ...           ...                         ...
# 283  284  4134   9         송파나루  02-2656-0934  서울특별시 송파구 백제고분로 지하446(방이동)
# 284  285  4135   9         한성백제  02-2656-0935   서울특별시 송파구 위례성대로 지하29(방이동)
# 285  286  4136   9  올림픽공원(한국체대)  02-2656-0936  서울특별시 송파구 양재대로 지하1233(방이동)
# 286  287  4137   9         둔촌오륜  02-2656-0937   서울특별시 강동구 강동대로 지하303(둔촌동)
# 287  288  4138   9       중앙보훈병원  02-2656-0938    서울특별시 강동구 동남로 지하625(둔촌동)
#
#                                 지번주소 del_staion     동추출
# 0      서울특별시 중구 남대문로5가 73-6 서울역(1호선)         서울  남대문로5가
# 1           서울특별시 중구 정동 5-5 시청역(1호선)         시청      정동
# 2         서울특별시 종로구 종로1가 54 종각역(1호선)         종각    종로1가
# 3     서울특별시 종로구 종로3가 10-5 종로3가역(1호선)       종로3가    종로3가
# 4     서울특별시 종로구 종로5가 82-1 종로5가역(1호선)       종로5가    종로5가
# ..                               ...        ...     ...
# 283       서울특별시 송파구 방이동 2 송파나루역(9호선)       송파나루     방이동
# 284   서울특별시 송파구 방이동 88-17 한성백제역(9호선)       한성백제     방이동
# 285  서울특별시 송파구 방이동 89-28 올림픽공원역(9호선)      올림픽공원     방이동
# 286   서울특별시 강동구 둔촌동 227-7 둔촌오륜역(9호선)       둔촌오륜     둔촌동
# 287   서울특별시 강동구 둔촌동 8-1 중앙보훈병원역(9호선)     중앙보훈병원     둔촌동
#
# [288 rows x 9 columns]

# %%
station_data['동추출'].unique()
# Out:
# array(['남대문로5가', '정동', '종로1가', '종로3가', '종로5가', '창신동', '신설동', '제기동', '전농동',
#        '숭인동', '서소문동', '을지로1가', '을지로3가', '을지로4가', '7가', '신당동', '하왕십리동',
#        '행당동', '성수동1가', '성수동2가', '화양동', '구의동', '신천동', '잠실동', '삼성동', '역삼동',
#        '서초동', '방배동', '사당동', '봉천동', '신림동', '신대방동', '구로동', '신도림동', '문래동3가',
#        '당산동3가', '당산동', '서교동', '동교동', '노고산동', '염리동', '아현동', '충정로3가', '용답동',
#        '신정동', '용두동', '지축동', '진관동', '갈현동', '대조동', '녹번동', '홍제동', '현저동',
#        '적선동', '안국동', '묘동', '필동2가', '장충동2가', '금호동4가', '옥수동', '신사동', '잠원동',
#        '반포동', '도곡동', '대치동', '일원동', '수서동', '가락동', '오금동', '상계동', '창동',
#        '수유동', '미아동', '길음동', '동선동4가', '삼선동1가', '명륜4가', '종로6가', '광희동2가',
#        '충무로2가', '남창동', '동자동', '갈월동', '한강로1가', '한강로2가', '용산동5가', '동작동',
#        '방화동', '공항동', '마곡동', '화곡동', '목동', '양평동2가', '영등포동5가', '영등포동1가',
#        '여의도동', '도화동', '공덕동', '평동', '', '돈의동', '주교동', '광희동1가', '금호동2가',
#        '마장동', '장안동', '능동', '광장동', '천호동', '길동', '명일동', '고덕동', '상일동', '둔촌동',
#        '방이동', '거여동', '마천동', '망월동', '덕풍동', '창우동', '불광동', '구산동', '증산동',
#        '성산동', '망원동', '합정동', '상수동', '창전동', '대흥동', '효창동', '용산동4가', '이태원동',
#        '한남동', '흥인동', '보문동1가', '안암동5가', '종암동', '하월곡동', '상월곡동', '석관동',
#        '월계동', '공릉동', '신내동', '장암동', '도봉동', '중계동', '하계동', '묵동', '중화동',
#        '상봉동', '면목동', '중곡동', '자양동', '청담동', '논현동', '상도동', '대방동', '신길동',
#        '대림동', '가산동', '철산동', '광명동', '천왕동', '온수동', '암사동', '성내동', '석촌동',
#        '문정동', '장지동', '복정동', '신흥동', '단대동', '수진동', '삼전동'], dtype=object)

# %%
get_data['region'] = del_gwalho(get_data['region'])

# %%
get_data['station'] = get_data['region'].apply(lambda x: re.sub(r'역.*$', '', x))

# %%
get_data['region'].unique()
# Out:
# array(['언주역', '녹사평역', '망원역', '구일역,', '노량진역', '방배역', '서울대벤처타운역', '사당역',
#        '구로디지털단지역', '응암역', '상봉역', '홍대입구역', '혜화역', '서울역', '수원시청역', '군자역',
#        '대흥역', '서울대벤쳐타운역', '구의역', '충정로역', '고려대역', '서울대입구역', '길음역',
#        '숭실대입구역', '청량리역', '건대입구역', '선릉역', '신림역', '송파역', '상월곡역,', '논현역',
#        '금호역', '신대방역', '중산역', '동묘앞역', '성신여대역', '독산역', '석계역', '신촌역',
#        '어린이대공원역', '상월곡역', '삼성중앙역', '약수역', '관악산역', '독바위역', '역삼역', '남성역',
#        '면목역', '외대앞역', '언주역,', '종합운동장역,', '신논현역', '공덕역', '제기동역', '삼전역',
#        '수유역', '북한산보국문역', '보문역', '동대입구역', '안암역', '상도역', '상수역', '숙대입구역',
#        '광운대역', '회기역', '서울대입구역에서', '이대역,', '신길역', '신사역', '낙성대역', '증산역',
#        '청담역', '봉천역', '오류동역', '돌곶이역', '선정릉역', '판교역', '동대문역사문화공원역', '신설동역',
#        '창신역'], dtype=object)

# %%
def dong_same(get_list,station_list,dong_list):
    same_dong_list = []
    for i in get_list:
        counter = 0
        for j in station_list:
            if i in j:
                same_dong_list.append(dong_list.loc[counter])
                break
            counter += 1
        else:
            if i == '서울대벤처타운':
                same_dong_list.append('신림동')
            elif i == '서울대벤쳐타운':
                same_dong_list.append('신림동')
            elif i == '노량진':
                same_dong_list.append('노량진동')
            elif i == '판교':
                same_dong_list.append('백현동')
            else:
                same_dong_list.append('')
    return same_dong_list

# %%
get_data['station_region'] = dong_same(get_data['station'],station_data['del_staion'],station_data['동추출'])

# %%
get_data['station_region'] = del_gwalho(get_data['station_region'])

# %%
get_data['station_region'].unique()
# Out:
# array(['논현동', '용산동4가', '망원동', '', '노량진동', '방배동', '신림동', '사당동', '구로동',
#        '신사동', '상봉동', '동교동', '명륜4가', '남대문로5가', '능동', '대흥동', '구의동', '충정로3가',
#        '종암동', '봉천동', '길음동', '상도동', '전농동', '화양동', '삼성동', '가락동', '상월곡동',
#        '금호동4가', '신대방동', '숭인동', '동선동4가', '월계동', '노고산동', '신당동', '불광동',
#        '면목동', '잠실동', '공덕동', '제기동', '수유동', '보문동1가', '장충동2가', '안암동5가',
#        '상수동', '갈월동', '염리동', '영등포동1가', '증산동', '청담동', '석관동', '백현동', '창신동',
#        '신설동'], dtype=object)

# %%
get_data = get_data[get_data['station_region'] != '']

# %%
get_data.query('station_region == ""')['station'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)
