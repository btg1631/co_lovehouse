# %%
import pandas as pd
df_DGDR = pd.read_csv('DGDR_trans.csv')
df_WOOJOO = pd.read_csv('WOOJOO_trans.csv')
df_DABANG = pd.read_csv('DABANG.csv')

# %%
df_merged = pd.concat(objs=[df_DGDR, df_WOOJOO])
df_merged[:3]
# Out:
#    Unnamed: 0.1  Unnamed: 0                       _id          title roomName  \
# 0             0           0  65d7f75e9f73bd1ba0885a08  동거동락X작심하우스 논현     201호
# 1             1           1  65d7f75e9f73bd1ba0885a09  동거동락X작심하우스 논현     202호
# 2             2           2  65d7f75e9f73bd1ba0885a0a  동거동락X작심하우스 논현     203호
#
#    gender  roomType   py  deposit  rentFee region  brandType  \
# 0       0         1  6.0   950000   355000    언주역          0
# 1       0         1  6.0   950000   355000    언주역          0
# 2       0         1  6.4   950000   440000    언주역          0
#
#                                           roomOption  \
# 0    세탁기  건조기  냉장고  전자레인지  밥솥  정수기   테이블  의자  세탁세...
# 1    세탁기  건조기  냉장고  전자레인지  밥솥  정수기   테이블  의자  세탁세...
# 2    세탁기  건조기  냉장고  전자레인지  밥솥  정수기   테이블  의자  세탁세...
#
#                                                  url  \
# 0  https://dgdr.co.kr/branch/view.html?search_tex...
# 1  https://dgdr.co.kr/branch/view.html?search_tex...
# ...

# %%
df_merged['region'] = df_merged['station_region']

# %%
df_merged = df_merged.drop(columns='station_region')
df_merged = df_merged.drop(columns='station')

# %%
df_merged
# Out:
#      Unnamed: 0.1  Unnamed: 0                       _id          title  \
# 0               0           0  65d7f75e9f73bd1ba0885a08  동거동락X작심하우스 논현
# 1               1           1  65d7f75e9f73bd1ba0885a09  동거동락X작심하우스 논현
# 2               2           2  65d7f75e9f73bd1ba0885a0a  동거동락X작심하우스 논현
# 3               3           3  65d7f75e9f73bd1ba0885a0b  동거동락X작심하우스 논현
# 4               4           4  65d7f75e9f73bd1ba0885a0c  동거동락X작심하우스 논현
# ..            ...         ...                       ...            ...
# 301           491         491  65d844d9586d871d4e26c6c0          299호점
# 302           492         492  65d844db586d871d4e26c6c1          299호점
# 303           493         493  65d844dd586d871d4e26c6c2          299호점
# 304           494         494  65d844df586d871d4e26c6c3          299호점
# 305           495         495  65d844e1586d871d4e26c6c4          299호점
#
#     roomName  gender  roomType   py  deposit  rentFee region  brandType  \
# ...

# %%
df_merged = pd.concat(objs=[df_merged, df_DABANG])

# %%
df_merged
# Out:
#      Unnamed: 0.1  Unnamed: 0                       _id          title  \
# 0             0.0           0  65d7f75e9f73bd1ba0885a08  동거동락X작심하우스 논현
# 1             1.0           1  65d7f75e9f73bd1ba0885a09  동거동락X작심하우스 논현
# 2             2.0           2  65d7f75e9f73bd1ba0885a0a  동거동락X작심하우스 논현
# 3             3.0           3  65d7f75e9f73bd1ba0885a0b  동거동락X작심하우스 논현
# 4             4.0           4  65d7f75e9f73bd1ba0885a0c  동거동락X작심하우스 논현
# ..            ...         ...                       ...            ...
# 549           NaN         549  65dab667ed6261510baeb718  매물번호 41950840
# 550           NaN         550  65dab66eed6261510baeb719  매물번호 42334987
# 551           NaN         551  65dab677ed6261510baeb71a  매물번호 42196226
# 552           NaN         552  65dab681ed6261510baeb71b  매물번호 42254016
# 553           NaN         553  65dab68ced6261510baeb71c  매물번호 42161102
#
#           roomName  gender  roomType     py    deposit  rentFee region  \
# ...

# %%
df_merged = df_merged.drop(columns='Unnamed: 0.1')
df_merged = df_merged.drop(columns='Unnamed: 0')

# %%
df_merged
# Out:
#                           _id          title       roomName  gender  roomType  \
# 0    65d7f75e9f73bd1ba0885a08  동거동락X작심하우스 논현           201호       0         1
# 1    65d7f75e9f73bd1ba0885a09  동거동락X작심하우스 논현           202호       0         1
# 2    65d7f75e9f73bd1ba0885a0a  동거동락X작심하우스 논현           203호       0         1
# 3    65d7f75e9f73bd1ba0885a0b  동거동락X작심하우스 논현           204호       0         1
# 4    65d7f75e9f73bd1ba0885a0c  동거동락X작심하우스 논현           205호       0         1
# ..                        ...            ...            ...     ...       ...
# 549  65dab667ed6261510baeb718  매물번호 41950840  매물번호 41950840       0         0
# 550  65dab66eed6261510baeb719  매물번호 42334987  매물번호 42334987       0         1
# 551  65dab677ed6261510baeb71a  매물번호 42196226  매물번호 42196226       0         0
# 552  65dab681ed6261510baeb71b  매물번호 42254016  매물번호 42254016       0         0
# 553  65dab68ced6261510baeb71c  매물번호 42161102  매물번호 42161102       0         1
#
# ...

# %%
df_merged.reset_index()
# Out:
#       index                       _id          title       roomName  gender  \
# 0         0  65d7f75e9f73bd1ba0885a08  동거동락X작심하우스 논현           201호       0
# 1         1  65d7f75e9f73bd1ba0885a09  동거동락X작심하우스 논현           202호       0
# 2         2  65d7f75e9f73bd1ba0885a0a  동거동락X작심하우스 논현           203호       0
# 3         3  65d7f75e9f73bd1ba0885a0b  동거동락X작심하우스 논현           204호       0
# 4         4  65d7f75e9f73bd1ba0885a0c  동거동락X작심하우스 논현           205호       0
# ...     ...                       ...            ...            ...     ...
# 1498    549  65dab667ed6261510baeb718  매물번호 41950840  매물번호 41950840       0
# 1499    550  65dab66eed6261510baeb719  매물번호 42334987  매물번호 42334987       0
# 1500    551  65dab677ed6261510baeb71a  매물번호 42196226  매물번호 42196226       0
# 1501    552  65dab681ed6261510baeb71b  매물번호 42254016  매물번호 42254016       0
# 1502    553  65dab68ced6261510baeb71c  매물번호 42161102  매물번호 42161102       0
#
# ...

# %%
df_merged.to_csv('merged_data.csv')
